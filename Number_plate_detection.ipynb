# %%
import numpy as np
import pytesseract
import cv2

# give path to pytesseract with tesseract location
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'

# %%
# read the image using OpenCV
image = cv2.imread("car4.jpg")
import matplotlib.pyplot as plt
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
txt = pytesseract.image_to_string(image)
# print it
print(txt)
# Out:
# FDLECAFSO30 ie

# %%
import re
str=''

for i in txt:

    if(i=='-'):
        break
    else:
        str=str+i
        #print(i,end='')
print("Vehicle No. : " ,str)
# Out:
# Vehicle No. :  FDLECAFSO30 ie

# %%
str=''

for k,i in enumerate(txt):
    #print(k,' ',i)
    if(i=='-'):
        break #exit from loop
    elif(k>=0 and k<=4):
        str=''
    else:
        str=str+i   #str=''+'R'   str='R'  str='R H'
        #print(i,end='')

print("Vehicle No. : " ,str)
# Out:
# Vehicle No. :  AFSO30 ie
